# %%
import pandas as pd

# %%
international_org = pd.read_csv(r'./datasets/international_org.csv')

# %%
international_org
# Out:
#   Organization Name  Headquater
# 0               FAO        Rome
# 1               ICJ   The Hague
# 2               IMF  Washington
# 3            UNESCO       Paris
# 4               UNO    New York
# 5        World Bank  Washington

# %%
international_org['Establish Year'] = 1945

# %%
international_org
# Out:
#   Organization Name  Headquater  Establish Year
# 0               FAO        Rome            1945
# 1               ICJ   The Hague            1945
# 2               IMF  Washington            1945
# 3            UNESCO       Paris            1945
# 4               UNO    New York            1945
# 5        World Bank  Washington            1945

# %%
imdb_rating = pd.read_csv(r'./datasets/imdb_rating.csv')

# %%
imdb_rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
del imdb_rating['duration']

# %%
imdb_rating
# Out:
#    star_rating                                          title      genre
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama

# %%
imdb_rating.loc[-1] = [9.4, 'Avengers: Infinity War', 'Action']
imdb_rating
# Out:
#     star_rating                                          title      genre
#  0          9.3                       The Shawshank Redemption      Crime
#  1          9.2                                  The Godfather      Crime
#  2          9.1                         The Godfather: Part II      Crime
#  3          9.0                                The Dark Knight     Action
#  4          8.9                                   Pulp Fiction      Crime
#  5          8.9                                   12 Angry Men      Drama
#  6          8.9                 The Good, the Bad and the Ugly    Western
#  7          8.9  The Lord of the Rings: The Return of the King  Adventure
#  8          8.9                               Schindler's List  Biography
#  9          8.9                                     Fight Club      Drama
# -1          9.4                         Avengers: Infinity War     Action

# %%
imdb_rating.index = imdb_rating.index + 1

# %%
imdb_rating = imdb_rating.sort_index()

# %%
imdb_rating
# Out:
#     star_rating                                          title      genre
# 0           9.4                         Avengers: Infinity War     Action
# 1           9.3                       The Shawshank Redemption      Crime
# 2           9.2                                  The Godfather      Crime
# 3           9.1                         The Godfather: Part II      Crime
# 4           9.0                                The Dark Knight     Action
# 5           8.9                                   Pulp Fiction      Crime
# 6           8.9                                   12 Angry Men      Drama
# 7           8.9                 The Good, the Bad and the Ugly    Western
# 8           8.9  The Lord of the Rings: The Return of the King  Adventure
# 9           8.9                               Schindler's List  Biography
# 10          8.9                                     Fight Club      Drama

# %%
imdb_rating.loc[10] = [5.5, 'The Mummy', 'Thriller']

# %%
imdb_rating
# Out:
#     star_rating                                          title      genre
# 0           9.4                         Avengers: Infinity War     Action
# 1           9.3                       The Shawshank Redemption      Crime
# 2           9.2                                  The Godfather      Crime
# 3           9.1                         The Godfather: Part II      Crime
# 4           9.0                                The Dark Knight     Action
# 5           8.9                                   Pulp Fiction      Crime
# 6           8.9                                   12 Angry Men      Drama
# 7           8.9                 The Good, the Bad and the Ugly    Western
# 8           8.9  The Lord of the Rings: The Return of the King  Adventure
# 9           8.9                               Schindler's List  Biography
# 10          5.5                                      The Mummy   Thriller

# %%
imdb_rating_1 = imdb_rating.drop(imdb_rating.index[[1,3]])

# %%
imdb_rating_1
# Out:
#     star_rating                                          title      genre
# 0           9.4                         Avengers: Infinity War     Action
# 2           9.2                                  The Godfather      Crime
# 4           9.0                                The Dark Knight     Action
# 5           8.9                                   Pulp Fiction      Crime
# 6           8.9                                   12 Angry Men      Drama
# 7           8.9                 The Good, the Bad and the Ugly    Western
# 8           8.9  The Lord of the Rings: The Return of the King  Adventure
# 9           8.9                               Schindler's List  Biography
# 10          5.5                                      The Mummy   Thriller

# %%
new_idx = ['movie_1', 'movie_2', 'movie_3', 'movie_4',
           'movie_5', 'movie_6', 'movie_7', 'movie_8',
           'movie_9', 'movie_10', 'movie_11']

# %%
imdb_rating.index = new_idx
imdb_rating
# Out:
#           star_rating                                          title  \
# movie_1           9.4                         Avengers: Infinity War
# movie_2           9.3                       The Shawshank Redemption
# movie_3           9.2                                  The Godfather
# movie_4           9.1                         The Godfather: Part II
# movie_5           9.0                                The Dark Knight
# movie_6           8.9                                   Pulp Fiction
# movie_7           8.9                                   12 Angry Men
# movie_8           8.9                 The Good, the Bad and the Ugly
# movie_9           8.9  The Lord of the Rings: The Return of the King
# movie_10          8.9                               Schindler's List
# movie_11          5.5                                      The Mummy
#
#               genre
# movie_1      Action
# movie_2       Crime
# movie_3       Crime
# movie_4       Crime
# movie_5      Action
# ...

# %%
imdb_rating = imdb_rating.reset_index()
imdb_rating
# Out:
#        index  star_rating                                          title  \
# 0    movie_1          9.4                         Avengers: Infinity War
# 1    movie_2          9.3                       The Shawshank Redemption
# 2    movie_3          9.2                                  The Godfather
# 3    movie_4          9.1                         The Godfather: Part II
# 4    movie_5          9.0                                The Dark Knight
# 5    movie_6          8.9                                   Pulp Fiction
# 6    movie_7          8.9                                   12 Angry Men
# 7    movie_8          8.9                 The Good, the Bad and the Ugly
# 8    movie_9          8.9  The Lord of the Rings: The Return of the King
# 9   movie_10          8.9                               Schindler's List
# 10  movie_11          5.5                                      The Mummy
#
#         genre
# 0      Action
# 1       Crime
# 2       Crime
# 3       Crime
# ...

# %%
imdb_rating = imdb_rating.drop(columns = ['index'])
imdb_rating
# Out:
#     star_rating                                          title      genre
# 0           9.4                         Avengers: Infinity War     Action
# 1           9.3                       The Shawshank Redemption      Crime
# 2           9.2                                  The Godfather      Crime
# 3           9.1                         The Godfather: Part II      Crime
# 4           9.0                                The Dark Knight     Action
# 5           8.9                                   Pulp Fiction      Crime
# 6           8.9                                   12 Angry Men      Drama
# 7           8.9                 The Good, the Bad and the Ugly    Western
# 8           8.9  The Lord of the Rings: The Return of the King  Adventure
# 9           8.9                               Schindler's List  Biography
# 10          5.5                                      The Mummy   Thriller
