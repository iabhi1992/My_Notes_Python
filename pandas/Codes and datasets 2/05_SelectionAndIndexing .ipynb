# %%
import pandas as pd

# %%
bike_share = pd.read_csv(r'./datasets/citibike_tripdata.csv')

# %%
bike_share.head(6)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
# ...

# %%
bike_share['bikeid'].head(6)
# Out:
# 0    33558
# 1    33593
# 2    29217
# 3    29662
# 4    15271
# 5    29298
# Name: bikeid, dtype: int64

# %%
bike_share[['start station id', 'end station id']].head(6)
# Out:
#    start station id  end station id
# 0              3639            3199
# 1              3681            3185
# 2              3194            3193
# 3              3185            3186
# 4              3207            3195
# 5              3194            3195

# %%
bike_share.at[4, 'start station id']
# Out:
# 3207

# %%
bike_share.at[4, 'start station id'] = 3274

# %%
bike_share.at[4, 'start station id']
# Out:
# 3274

# %%
new_bike_share = bike_share[ : 6]

# %%
new_bike_share
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3274
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
# ...

# %%
idx = ['row_1', 'row_2', 'row_3',
       'row_4', 'row_5', 'row_6']

# %%
new_bike_share.index = idx

# %%
new_bike_share.index
# Out:
# Index(['row_1', 'row_2', 'row_3', 'row_4', 'row_5', 'row_6'], dtype='object')

# %%
new_bike_share
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3274        Oakland Ave            3195          Sip Ave
# ...

# %%
new_bike_share.loc['row_2']
# Out:
# tripduration                          1482
# starttime              2018-05-01 01:31:10
# stoptime               2018-05-01 01:55:53
# start station id                      3681
# start station name                Grand St
# end station id                        3185
# end station name                 City Hall
# bikeid                               33593
# name_localizedValue                24 Hour
# usertype                          Customer
# Name: row_2, dtype: object

# %%
new_bike_share.loc['row_1' : 'row_4']
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# row_2   33593                                  24 Hour    Customer
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# ...

# %%
new_bike_share.loc['row_3' :, 'tripduration' : 'end station id']
# Out:
#        tripduration            starttime             stoptime  \
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id
# row_3              3194    McGinley Square            3193
# row_4              3185          City Hall            3186
# row_5              3274        Oakland Ave            3195
# row_6              3194    McGinley Square            3195

# %%
new_bike_share.loc[new_bike_share['tripduration'] > 200]
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_5              3274        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# row_2   33593                                  24 Hour    Customer
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# ...

# %%
new_bike_share.loc[new_bike_share['tripduration'] > 200,
                   'tripduration' : 'end station id']
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id
# row_1              3639         Harborside            3199
# row_2              3681           Grand St            3185
# row_3              3194    McGinley Square            3193
# row_5              3274        Oakland Ave            3195

# %%
new_bike_share.loc[new_bike_share['tripduration'] > 200, 
                                 ['start station id']]
# Out:
#        start station id
# row_1              3639
# row_2              3681
# row_3              3194
# row_5              3274

# %%
new_bike_share.iloc[4]
# Out:
# tripduration                           303
# starttime              2018-05-01 04:27:12
# stoptime               2018-05-01 04:32:16
# start station id                      3274
# start station name             Oakland Ave
# end station id                        3195
# end station name                   Sip Ave
# bikeid                               15271
# name_localizedValue      Annual Membership
# usertype                        Subscriber
# Name: row_5, dtype: object

# %%
new_bike_share.iloc[3 : 8]
# Out:
#        tripduration            starttime             stoptime  \
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3274        Oakland Ave            3195          Sip Ave
# row_6              3194    McGinley Square            3195          Sip Ave
#
#        bikeid name_localizedValue    usertype
# row_4   29662             24 Hour    Customer
# row_5   15271   Annual Membership  Subscriber
# row_6   29298   Annual Membership  Subscriber

# %%
new_bike_share.iloc[3 : , 0 : 6]
# Out:
#        tripduration            starttime             stoptime  \
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id
# row_4              3185          City Hall            3186
# row_5              3274        Oakland Ave            3195
# row_6              3194    McGinley Square            3195

# %%
new_bike_share.iloc[2 : 5 , 0 : 6]
# Out:
#        tripduration            starttime             stoptime  \
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id
# row_3              3194    McGinley Square            3193
# row_4              3185          City Hall            3186
# row_5              3274        Oakland Ave            3195

# %%
new_bike_share.iloc[[2, 3, 4], : ]
# Out:
#        tripduration            starttime             stoptime  \
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3274        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_4   29662                                  24 Hour    Customer
# row_5   15271                        Annual Membership  Subscriber

# %%
new_bike_share
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3274        Oakland Ave            3195          Sip Ave
# ...

# %%
new_bike_share[new_bike_share['tripduration'] > 180]
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3274        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# ...

# %%
new_bike_share[new_bike_share['usertype'] == 'Subscriber']
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_5              3274        Oakland Ave            3195          Sip Ave
# row_6              3194    McGinley Square            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_5   15271                        Annual Membership  Subscriber
# ...

# %%
new_bike_share[(new_bike_share['usertype'] == 'Subscriber') & 
               (new_bike_share['bikeid'] < 30000) ]
# Out:
#        tripduration            starttime             stoptime  \
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_5              3274        Oakland Ave            3195          Sip Ave
# row_6              3194    McGinley Square            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_5   15271                        Annual Membership  Subscriber
# row_6   29298                        Annual Membership  Subscriber

# %%
new_bike_share[(new_bike_share['usertype'] == 'Customer') |
               (new_bike_share['bikeid'] < 35000) ]
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3274        Oakland Ave            3195          Sip Ave
# ...

# %%
new_bike_share[~(new_bike_share['usertype'] == 'Subscriber')]
# Out:
#        tripduration            starttime             stoptime  \
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
#
#        start station id start station name  end station id end station name  \
# row_2              3681           Grand St            3185        City Hall
# row_4              3185          City Hall            3186    Grove St PATH
#
#        bikeid name_localizedValue  usertype
# row_2   33593             24 Hour  Customer
# row_4   29662             24 Hour  Customer
