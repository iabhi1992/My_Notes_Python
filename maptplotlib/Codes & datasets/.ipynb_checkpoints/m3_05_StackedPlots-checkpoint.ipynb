# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
corn_data = pd.read_csv('Datasets/USDAProj_Corn.csv')
corn_data.head()
# Out:
#          Date  Area Planted  Area Harvested  Yield  Beginning Stocks  \
# 0  2007/05/11          90.5            82.9  150.3             937.0
# 1  2007/06/11          90.5            82.9  150.3             987.0
# 2  2007/07/12          92.9            85.4  150.3            1137.0
# 3  2007/08/10          92.9            85.4  152.8            1137.0
# 4  2007/09/12          92.9            85.4  155.8            1142.0
#
#    Production  Imports  Total Supply  Feed and Residual     FSI  \
# 0     12460.0     15.0       13412.0             5700.0  4790.0
# 1     12460.0     15.0       13462.0             5700.0  4790.0
# 2     12840.0     15.0       13992.0             5700.0  4790.0
# 3     13054.0     15.0       14206.0             5750.0  4790.0
# 4     13308.0     15.0       14465.0             5850.0  4690.0
#
#               ...               Southeast Asia DomesticTotal  \
# 0             ...                                      21.35
# ...

# %%
#corn_data['Date'] = pd.to_datetime(corn_data['Date'])

# %%
#a = stock_data['AAPL']
#b = stock_data['GOOG']
#c = stock_data['IBM']

# %%
x = corn_data['Date']
type(x)
# Out:
# pandas.core.series.Series

# %%
y = np.vstack([corn_data['Brazil Production'], 
               corn_data['Argentina Production'],
               corn_data['European Union Production']])
type(y)
# Out:
# numpy.ndarray

# %%
labels = ['Brazil Production', 
          'Argentina Production',
          'EU Production']

# %%
plt.stackplot(x, y, 
              labels=labels)

plt.ylim(0,200)
plt.legend(loc='upper left')

plt.show()

# %%
colors = ['pink', 
          'tomato', 
          'skyblue']

# %%
plt.stackplot(x, y, 
              labels=labels,
              colors=colors, 
              edgecolor='grey')

plt.ylim(0,200)

plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### Stemplots

# %%
corn_data[['Brazil Production', 
          'Argentina Production',
          'European Union Production']] = corn_data[['Brazil Production', 
                                                     'Argentina Production',
                                                     'European Union Production']].diff()
corn_data.head()
# Out:
#          Date  Area Planted  Area Harvested  Yield  Beginning Stocks  \
# 0  2007/05/11          90.5            82.9  150.3             937.0
# 1  2007/06/11          90.5            82.9  150.3             987.0
# 2  2007/07/12          92.9            85.4  150.3            1137.0
# 3  2007/08/10          92.9            85.4  152.8            1137.0
# 4  2007/09/12          92.9            85.4  155.8            1142.0
#
#    Production  Imports  Total Supply  Feed and Residual     FSI  \
# 0     12460.0     15.0       13412.0             5700.0  4790.0
# 1     12460.0     15.0       13462.0             5700.0  4790.0
# 2     12840.0     15.0       13992.0             5700.0  4790.0
# 3     13054.0     15.0       14206.0             5750.0  4790.0
# 4     13308.0     15.0       14465.0             5850.0  4690.0
#
#               ...               Southeast Asia DomesticTotal  \
# 0             ...                                      21.35
# ...

# %%
aapl_data = pd.read_csv('Datasets/AAPL.csv')
aapl_data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 1  2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2  2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 3  2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 4  2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
#
#       Volume
# 0  142718700
# 1  280258200
# 2  358539800
# 3  358532900
# 4  220230600

# %%
aapl_data[['Adj Close']] = aapl_data[['Adj Close']].diff()

aapl_data.head()
# Out:
#          Date        Open        High         Low       Close  Adj Close  \
# 0  2014-09-29  100.589996  100.690002   98.040001   99.620003        NaN
# 1  2014-10-06   99.949997  102.379997   98.309998  100.730003   1.041954
# 2  2014-10-13  101.330002  101.779999   95.180000   97.669998  -2.872452
# 3  2014-10-20   98.320000  105.489998   98.220001  105.220001   7.087250
# 4  2014-10-27  104.849998  108.040001  104.699997  108.000000   2.609634
#
#       Volume
# 0  142718700
# 1  280258200
# 2  358539800
# 3  358532900
# 4  220230600

# %%
plt.figure(figsize=(10,6))

plt.stem(aapl_data['Adj Close'])

plt.title('')

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.stem(aapl_data['Adj Close'],
         markerfmt = 'g_',
         linefmt = 'r--',
         basefmt = 'b:')

plt.title('AAPL')

plt.show()
