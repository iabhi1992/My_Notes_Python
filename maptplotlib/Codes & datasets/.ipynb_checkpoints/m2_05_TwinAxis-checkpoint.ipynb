# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
goog = pd.read_csv('Datasets/GOOG.csv')
goog.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2007-09-28  281.668030  282.934784  280.237335  281.802155  281.802155
# 1  2007-10-01  283.143433  290.286957  282.964600  289.392792  289.392792
# 2  2007-10-02  289.805084  296.476715  288.130981  290.306824  290.306824
# 3  2007-10-03  291.230835  292.591980  288.304840  290.123016  290.123016
# 4  2007-10-04  290.654572  290.654572  286.665527  287.644165  287.644165
#
#      Volume
# 0   5313200
# 1   9483800
# 2  14226900
# 3   7809400
# 4   6012200

# %%
goog = goog[['Date', 'Adj Close', 'Volume']].head(40)
goog
# Out:
#           Date   Adj Close    Volume
# 0   2007-09-28  281.802155   5313200
# 1   2007-10-01  289.392792   9483800
# 2   2007-10-02  290.306824  14226900
# 3   2007-10-03  290.123016   7809400
# 4   2007-10-04  287.644165   6012200
# 5   2007-10-05  295.105621  10203200
# 6   2007-10-08  302.840302  10121300
# 7   2007-10-09  305.602356  17649500
# 8   2007-10-10  310.674377  10841200
# 9   2007-10-11  308.990326  23751300
# 10  2007-10-12  316.635590  13736100
# 11  2007-10-15  308.051422  13977800
# 12  2007-10-16  306.009705  12128900
# 13  2007-10-17  314.693237  12139300
# 14  2007-10-18  317.743378  24738100
# 15  2007-10-19  320.271942  31783200
# 16  2007-10-22  323.272430  13415400
# 17  2007-10-23  335.701599  13675600
# 18  2007-10-24  335.726410  14904600
# 19  2007-10-25  332.095032  11666200
# 20  2007-10-26  335.120361   6751400
# 21  2007-10-29  337.420410   6172400
# 22  2007-10-30  345.140198  13890900
# 23  2007-10-31  351.215668  13842900
# 24  2007-11-01  349.332916  13139200
# 25  2007-11-02  353.326935  11758900
# 26  2007-11-05  360.480408  17882900
# 27  2007-11-06  368.498260  16982200
# 28  2007-11-07  364.101868  16654500
# 29  2007-11-08  344.678192  33239100
# 30  2007-11-09  329.839722  22924200
# 31  2007-11-12  313.992767  20587600
# 32  2007-11-13  328.140747  17000500
# 33  2007-11-14  318.766724  16294500
# 34  2007-11-15  312.790588  14025900
# 35  2007-11-16  314.767731  18203100
# 36  2007-11-19  310.902863  11126600
# 37  2007-11-20  322.174561  19809000
# 38  2007-11-21  328.125854  14118200
# 39  2007-11-23  336.163574   5512900

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(10)
fig.set_figheight(5)

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(10)
fig.set_figheight(5)

ax_tempF.set_xlabel('Date')

ax_tempF.tick_params(axis = 'x',
                    bottom=False,
                    labelbottom=False)

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(10)
fig.set_figheight(5)

ax_tempF.set_xlabel('Date')

ax_tempF.tick_params(axis = 'x',
                    bottom=False,
                    labelbottom=False)

ax_tempF.set_ylabel('Adj Close', 
                    color='magenta',
                    size='x-large')

ax_tempF.tick_params(axis='y', 
                     labelcolor='magenta', 
                     labelsize='large')

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(10)
fig.set_figheight(5)

ax_tempF.set_xlabel('Date')

ax_tempF.tick_params(axis = 'x',
                    bottom=False,
                    labelbottom=False)

ax_tempF.set_ylabel('Adj Close', 
                    color='magenta',
                    size='x-large')

ax_tempF.tick_params(axis='y', 
                     labelcolor='magenta', 
                     labelsize='large')

ax_tempF.plot(goog['Date'], 
              goog['Adj Close'], 
              color='magenta')

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(10)
fig.set_figheight(5)

ax_tempF.set_xlabel('Date')

ax_tempF.tick_params(axis = 'x',
                    bottom=False,
                    labelbottom=False)

ax_tempF.set_ylabel('Adj Close', 
                    color='magenta',
                    size='x-large')

ax_tempF.tick_params(axis='y', 
                     labelcolor='magenta', 
                     labelsize='large')

ax_tempF.plot(goog['Date'], 
              goog['Adj Close'], 
              color='magenta')

ax_precip = ax_tempF.twinx()

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(10)
fig.set_figheight(5)

ax_tempF.set_xlabel('Date')

ax_tempF.tick_params(axis = 'x',
                    bottom=False,
                    labelbottom=False)

ax_tempF.set_ylabel('Adj Close', 
                    color='magenta',
                    size='x-large')

ax_tempF.tick_params(axis='y', 
                     labelcolor='magenta', 
                     labelsize='large')

ax_tempF.plot(goog['Date'], 
              goog['Adj Close'], 
              color='magenta')

ax_precip = ax_tempF.twinx()

ax_precip.set_ylabel('Volume', 
                     color='limegreen', 
                     size='x-large') 

ax_precip.tick_params(axis='y', 
                      labelcolor='limegreen',
                      labelsize='large')

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(10)
fig.set_figheight(5)

ax_tempF.set_xlabel('Date')

ax_tempF.tick_params(axis = 'x',
                    bottom=False,
                    labelbottom=False)

ax_tempF.set_ylabel('Adj Close', 
                    color='magenta',
                    size='x-large')

ax_tempF.tick_params(axis='y', 
                     labelcolor='magenta', 
                     labelsize='large')

ax_tempF.plot(goog['Date'], 
              goog['Adj Close'], 
              color='magenta')

ax_precip = ax_tempF.twinx()

ax_precip.set_ylabel('Volume', 
                     color='limegreen', 
                     size='x-large') 

ax_precip.tick_params(axis='y', 
                      labelcolor='limegreen',
                      labelsize='large')

ax_precip.plot(goog['Date'], 
         goog['Volume'], 
         color='limegreen')
