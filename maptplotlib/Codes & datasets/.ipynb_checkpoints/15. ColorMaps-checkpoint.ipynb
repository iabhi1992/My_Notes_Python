# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
corn_data = pd.read_csv('Datasets/USDAProj_Corn.csv')
corn_data.head()
# Out:
#          Date  Area Planted  Area Harvested  Yield  Beginning Stocks  \
# 0  2007/05/11          90.5            82.9  150.3             937.0
# 1  2007/06/11          90.5            82.9  150.3             987.0
# 2  2007/07/12          92.9            85.4  150.3            1137.0
# 3  2007/08/10          92.9            85.4  152.8            1137.0
# 4  2007/09/12          92.9            85.4  155.8            1142.0
#
#    Production  Imports  Total Supply  Feed and Residual     FSI  \
# 0     12460.0     15.0       13412.0             5700.0  4790.0
# 1     12460.0     15.0       13462.0             5700.0  4790.0
# 2     12840.0     15.0       13992.0             5700.0  4790.0
# 3     13054.0     15.0       14206.0             5750.0  4790.0
# 4     13308.0     15.0       14465.0             5850.0  4690.0
#
#               ...               Southeast Asia DomesticTotal  \
# 0             ...                                      21.35
# 1             ...                                      21.35
# 2             ...                                      21.35
# 3             ...                                      21.35
# 4             ...                                      21.35
#
#    Southeast Asia Exports  Southeast Asia EndingStocks  \
# 0                    0.24                         1.95
# 1                    0.24                         1.95
# 2                    0.24                         1.97
# 3                    0.24                         1.92
# 4                    0.24                         1.77
#
#    European Union BeginningStocks  European Union Production  \
# 0                           10.42                      55.37
# 1                           10.72                      55.72
# 2                           10.72                      55.23
# 3                           10.72                      48.43
# 4                           10.62                      46.94
#
#    European Union Imports  European Union DomesticFeed  \
# 0                     3.5                         45.3
# 1                     3.5                         45.8
# 2                     3.5                         45.8
# 3                     6.0                         45.8
# 4                     8.0                         46.5
#
#    European Union DomesticTotal  European Union Exports  \
# 0                          60.3                     0.3
# 1                          60.8                     0.3
# 2                          60.8                     0.3
# 3                          60.8                     0.3
# 4                          61.5                     0.3
#
#    European Union EndingStocks
# 0                         8.69
# 1                         8.84
# 2                         8.35
# 3                         4.05
# 4                         3.76
#
# [5 rows x 113 columns]

# %%
x = corn_data['Date']

# %%
y = np.vstack([corn_data['Brazil Production'], 
               corn_data['Argentina Production'],
               corn_data['European Union Production'],])
y[0]
# Out:
# array([50. , 50. , 50. , 50. , 51. , 50. , 50. , 50. , 50. , 50. , 53. ,
#        53. , 56. , 58. , 57.5, 57.5, 58.6, 58.6, 58.6, 58.6, 58.6, 58.6,
#        58.6, 58.6])

# %%
labels = ['Brazil Production', 
          'Argentina Production',
          'EU Production']
type(y)
# Out:
# numpy.ndarray

# %%
plt.stackplot(x, y, 
              labels=labels)

plt.ylim(0,200)

plt.legend(loc='upper left')

plt.show()

# %%
colormap = ['magenta','pink','skyblue']

# %%
fig, ax = plt.subplots()

ax.set_prop_cycle('color', colormap)

ax.stackplot(x, y, 
             labels=labels)

plt.ylim(0,200)

ax.legend(loc='upper left')

plt.show()

# %%
colormap = ['magenta','skyblue']

# %%
fig, ax = plt.subplots()

ax.set_prop_cycle('color', colormap)

ax.stackplot(x, y, 
             labels=labels)

plt.ylim(0,200)

ax.legend(loc='upper left')

plt.show()

# %%
sp = plt.stackplot(x, y, 
              labels=labels)

plt.ylim(0,200)

plt.legend(loc='upper left')

plt.show()

# %%
rainbow_cmap = plt.get_cmap('rainbow', len(sp))
rainbow_cmap

# %%
fig, ax = plt.subplots()

sp = ax.stackplot(x, y, 
             labels=labels)

plt.ylim(0,200)

for i in range(len(sp)):
    sp[i].set_facecolor(rainbow_cmap(i))

# %%
for i in range(5):
    print(rainbow_cmap(i))
# Out:
# (0.5, 0.0, 1.0, 1.0)
# (0.5, 1.0, 0.7071067811865476, 1.0)
# (1.0, 1.2246467991473532e-16, 6.123233995736766e-17, 1.0)
# (1.0, 1.2246467991473532e-16, 6.123233995736766e-17, 1.0)
# (1.0, 1.2246467991473532e-16, 6.123233995736766e-17, 1.0)

# %%
x = np.arange(100)

y = x

# %%
fig, ax = plt.subplots()

ax.scatter(x, y, 
           c=y)

plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(x, y, 
           c=y, 
           cmap='rainbow')

plt.show()

# %%
import matplotlib.colors as colors

# %%
x = np.arange(1, 10)
y = np.log10(x)

# %%
fig, ax = plt.subplots()

ax.scatter(x, y, 
           c=y, 
           cmap='rainbow')

plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(x, y, 
           c=y,
           cmap='rainbow',
           norm=colors.LogNorm())

plt.show()

# %%
x = np.arange(1, 100)
y = np.log10(x)

# %%
fig, ax = plt.subplots()

ax.scatter(x, y, 
           c=y, 
           cmap='rainbow')

ax.set_yscale('log')

plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(x, y, 
           c=y, 
           cmap='rainbow',
           norm=colors.LogNorm())

ax.set_yscale('log')

plt.show()
