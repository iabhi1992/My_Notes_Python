# %% [markdown]
# * interactive mode mode will work without plt.show
# * non Interactive mode will work plt.show, it is connecting each cells

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 2.2.2

# %%
matplotlib.is_interactive()
# Out:
# False

# %%
matplotlib.interactive(False)

# %%
import matplotlib.pyplot as plt

plt.ioff()
matplotlib.is_interactive()
# Out:
# False

# %% [markdown]
# We are using pyplot to plot a simple straight line.
#
# * Here we are giving x and y coordinates

# %%
plt.plot([3, 5, 7, 9], 
         [6, 10, 14, 18])

# %%
plt.show()

# %% [markdown]
# * Switch to interactive mode

# %%
matplotlib.interactive(True)

# %%
plt.plot([3, 5, 7, 9], 
         [6, 10, 14, 18])

# %% [markdown]
# * Adding color and line width

# %%
plt.plot([3, 5, 7, 9], 
         [6, 14, 6, 16],
         
         color='fuchsia',
         linewidth=3)
