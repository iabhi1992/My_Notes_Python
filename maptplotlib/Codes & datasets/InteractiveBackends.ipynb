# %% [markdown]
# * Here we are getting list of backends

# %%
# %matplotlib --list
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %%
import matplotlib

# %% [markdown]
# * Checking it is interactive or not

# %%
matplotlib.is_interactive()
# Out:
# False

# %%
matplotlib.interactive(True)

# %% [markdown]
# * Checking what backend we are using

# %%
matplotlib.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %% [markdown]
# * nbagg is the backend we are using here

# %%
matplotlib.use('nbagg')

# %%
matplotlib.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt

plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
plt.plot([3, 5, 7, 9],
        [6, 10,14, 18])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# * We are adding title here, that will display on the above figure

# %%
plt.title('Interactive plot' ,
          color='limegreen',
          
          size=18,
          style='italic',
          weight='bold')
# Out:
# Text(0.5,1,'interactive plot')

# %% [markdown]
# * The label also will appear on the above plot

# %%
plt.xlabel('x values')
# Out:
# Text(0.5,0,'x values')

# %%
plt.ylabel('y values')
# Out:
# Text(0,0.5,'y values')
