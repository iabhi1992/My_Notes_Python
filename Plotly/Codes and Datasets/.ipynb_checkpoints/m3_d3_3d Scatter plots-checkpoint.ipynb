# %%
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd
import numpy as np
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# **We produce 5 sets of values**
#
# A 3D bubble chart can be used to represent multiple dimensions of data. Aside from the 3 spatial dimensions, markers can represent more information from their size and color giving a total of 5 features which can be represented

# %%
n = 100

random_x = np.random.randn(n)

random_y = np.random.randn(n)

random_z = np.random.randn(n)

random_a = np.random.randn(n)

random_b = np.arange(1000,1050)

# %% [markdown]
# **The random_b list was between 1000 to 1049 to appear clearly in the plot**

# %% [markdown]
# **Generate a 3D scatter trace using the 5 dimensions**
#
# We use a color scale to pick the bubble colors.

# %%
trace = go.Scatter3d(x = random_x,
                     y = random_y,
                     z = random_z,
                   
                     mode = 'markers',
                     
                     marker = dict(color = random_a,
                                   colorscale = 'Jet',
                                   
                                   size = random_b,
                                   sizemode = 'area',
                                   showscale = True
                                   )
                    )
data=[trace]

# %%
offline.iplot(data)
# Out:
# <div id="379d7575-851b-40d9-ac7d-8756195a7242" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("379d7575-851b-40d9-ac7d-8756195a7242", [{"marker": {"color": [-0.01819025480182823, -1.460715850917962, -1.3850387477274724, 0.6816591717656638, -0.0016943650277461788, -0.4748082479213104, 1.7468105793851834, 0.9120462523442497, -0.5333065745171853, 0.9959837005056268, 0.8850932982010601, 1.1055572136088556, 0.3884615382942444, 0.8108675291815817, -0.8081569023608207, 0.9835038968824603, 1.141612575560573, 0.25586519806074015, -0.23652120825853834, -1.258914970493055, 0.3485438033341117, 0.8436463622856181, -0.129636331860285, 0.8683151642628624, 1.5038418262356759, -0.3348513825921358, -0.7575177662544416, 0.4791707840403093, -0.05467736498141791, -0.5450976173736005, 0.3790096794993354, 0.8870302330252041, 0.5455428939835734, 0.0655811889501017, 0.6572044997616381, 1.46778965178186, -0.27757565240976473, 1.0233139852879465, 1.9749906901131102, 2.3532344163335073, -1.1822720874242647, 0.7327767309565407, -0.10756784681131801, -0.624838031907679, 1.1895161682380575, -0.8545954220940797, 1.477199462851382, -1.1656924093227818, -0.10188434916306832, -0.13192804438414998, 0.5656655544317779, -0.18905908813362665, -0.8254633683378706, -0.3714359441777678, 1.2601754542935169, -0.451688604903043, 1.6994757783865868, -1.409865652362889, 0.34005114768956485, -3.038448720669438, -1.4730729256069923, 0.2494354398537306, 0.45134390006788194, -0.6675836352639032, -0.2678124560671572, -0.19348883133317182, -0.6409305249284016, 1.335248770477654, 0.3052500140823281, 0.32865073089224545, 0.14504925659221723, -0.8565129169267457, 0.2125556715602432, -0.16205497640811514, -0.01858568652017489, -0.38356001087040104, 1.971696045371417, -0.7169632843889125, 1.4268425032725693, -0.7351031514137806, -0.8275590639193849, -0.11693847006514582, -0.41309375484649025, -0.30448124295937967, 0.3246193133401026, 0.008402457685360479, -2.623861094461404, 2.618999684518525, -1.0201341489536655, -0.13914227167566934, -0.4406626518163115, -2.5371205772148993, 0.14694013292699704, 0.09314683653953813, 0.16983336601286453, 1.210275385853737, 2.107464521678159, -0.47183268525369654, -2.429297963223427, -0.5066284839183223], "colorscale": "Jet", "showscale": true, "size": [1000.0, 1001.0, 1002.0, 1003.0, 1004.0, 1005.0, 1006.0, 1007.0, 1008.0, 1009.0, 1010.0, 1011.0, 1012.0, 1013.0, 1014.0, 1015.0, 1016.0, 1017.0, 1018.0, 1019.0, 1020.0, 1021.0, 1022.0, 1023.0, 1024.0, 1025.0, 1026.0, 1027.0, 1028.0, 1029.0, 1030.0, 1031.0, 1032.0, 1033.0, 1034.0, 1035.0, 1036.0, 1037.0, 1038.0, 1039.0, 1040.0, 1041.0, 1042.0, 1043.0, 1044.0, 1045.0, 1046.0, 1047.0, 1048.0, 1049.0], "sizemode": "area"}, "mode": "markers", "x": [0.9552476708075557, 0.09119632780733047, -0.4720951191816153, -0.31928513243183876, -1.278469421084492, -0.9039725417665342, 1.424426545633515, 0.8084038643850421, 0.9349234545193483, -0.04950450390933013, -0.8152693688299884, 0.7307103132560241, -1.483487166066796, -1.4214434061970616, 0.5978806021199452, -2.9086656046485775, 1.317545419712702, 0.07544583352283904, -0.8358923544284327, -0.027424441000907778, 0.5009464582485429, -0.17890942126873038, 1.4947000674304782, -1.2011929800286913, -0.38007591527096274, 0.5405713892122102, -0.42213794197058496, 0.03959345241987368, 0.1703539369963559, -0.20218526888078628, -0.21655550393674095, -0.07481256807102855, -0.5300160811659869, 1.1720139666512457, 0.12876461152480212, 0.12627976942954897, -0.48398860392038623, 0.3826001634481389, 0.24273480502762154, 0.5327448403206587, -0.2394151653543915, 0.7192069257985949, -1.6554454394674534, -0.8153561663410162, 1.7092746003204204, 1.090824658741245, -0.8743234782900172, -1.1520013400203866, 0.9818129254648585, -0.688065626081573, 0.4939709393586551, 0.9198251361051349, -0.90729966831344 ...

# %% [markdown]
# **we need to zoom the plot for better visualization**

# %% [markdown]
# **3D Bubble chart to plot real data**
#
# **download the dataset**
#
# dataset location:https://www.kaggle.com/fernandol/countries-of-the-world

# %%
country_data = pd.read_csv('./datasets/countries_of_the_world.csv', decimal=",")
country_data.tail()
# Out:
#              Country                               Region  Population  \
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area_sq/mi  Pop.Density_(per_sq._mi.)  Coastline (coast/area ratio)  \
# 222        5860                      419.9                          0.00
# 223      266000                        1.0                          0.42
# 224      527970                       40.6                          0.36
# 225      752614                       15.3                          0.00
# 226      390580                       31.3                          0.00
#
#      Net migration  Infant mortality (per 1000 births)  GDP($percapita)  \
# 222           2.98                               19.62            800.0
# 223            NaN                                 NaN              NaN
# 224           0.00                               61.50            800.0
# 225           0.00                               88.29            800.0
# 226           0.00                               67.69           1900.0
#
#      Literacy(%)  Phones(per1000)  Arable (%)  Crops (%)  Other (%)  Climate  \
# 222          NaN            145.2       16.90      18.97      64.13      3.0
# 223          NaN              NaN        0.02       0.00      99.98      1.0
# 224         50.2             37.2        2.78       0.24      96.98      1.0
# 225         80.6              8.2        7.08       0.03      92.90      2.0
# 226         90.7             26.8        8.32       0.34      91.34      2.0
#
#      Birthrate  Deathrate  Agriculture  Industry  Service
# 222      31.67       3.92        0.090     0.280    0.630
# 223        NaN        NaN          NaN       NaN    0.400
# 224      42.89       8.30        0.135     0.472    0.393
# 225      41.00      19.93        0.220     0.290    0.489
# 226      28.01      21.84        0.179     0.243    0.579

# %% [markdown]
# #### Define the 3D scatter plot
#
# We convey the following information in the plot:
# * <b>x-axis</b> represents the Birthrate
# * <b>y-axis</b> denotes the GDP ($ per capita)
# * <b>z-axis</b> conveys the Literacy(%)
# * <b>marker size</b> portrays the size of the Population
# * <b>marker colors</b> represent the Arable (%)

# %%
trace = go.Scatter3d(x = country_data['Birthrate'],
                     y = country_data['GDP($percapita)'],
                     z = country_data['Literacy(%)'],
                     
                     text =  country_data['Country'],
                     
                     mode='markers',
                     marker=dict(sizemode='area',
                                 sizeref=100000,
                                 size=country_data['Population'],
                                 color = country_data['Arable (%)'],
                                 colorscale='Viridis',
                                 showscale = True
                                 )
                    )
data=[trace]

# %% [markdown]
# **Define the layout**

# %%
layout = go.Layout(width=800, 
                   height=800, 
                   title = 'Population of the World',
                   
                   scene = dict(xaxis=dict(title='Birthrate',
                                           color='Blue',
                                           titlefont=dict(color='Black')
                                          ),
                                
                                yaxis=dict(title='GDP per capita',
                                           color='Blue',
                                           titlefont=dict(color='Black')
                                          ),
                                
                                zaxis=dict(title='Literacy rate',
                                           color='Blue',
                                           titlefont=dict(color='Black')),
                                
                                bgcolor = '#B0C4DE'
                  )
     )

# %% [markdown]
# **Plot the figure**
#
# we need to zoom in to view the smaller ones.

# %%
fig=go.Figure(data=data, 
              layout=layout)

offline.iplot(fig)
# Out:
# <div id="8f97ff05-8526-4e47-a71e-cc55ec93cfbf" style="height: 800px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '8f97ff05-8526-4e47-a71e-cc55ec93cfbf',
#             [{"marker": {"color": [12.13, 21.09, 3.22, 10.0, 2.22, 2.41, 0.0, 18.18, 12.31, 17.55, 10.53, 6.55, 16.91, 19.63, 0.8, 2.82, 62.11, 37.21, 29.55, 23.28, 2.85, 18.08, 20.0, 3.09, 2.67, 13.6, 0.65, 6.96, 20.0, 0.57, 40.02, 14.43, 15.19, 35.05, 20.96, 12.81, 4.96, 9.68, 3.85, 3.1, 2.86, 2.65, 15.4, 2.42, 35.87, 2.96, 0.51, 17.39, 4.41, 9.75, 26.09, 33.05, 7.79, 39.8, 54.02, 0.04, 6.67, 22.65, 4.71, 5.85, 2.87, 31.85, 4.63, 4.95, 16.04, 10.71, 2.14, 10.95, 7.19, 33.53, 0.14, 0.82, 1.26, 25.0, 28.95, 11.44, 33.85, 16.26, 0.0, 21.1, 0.0, 5.88, 11.24, 9.09, 12.54, null, 3.63, 10.67, 2.44, 28.3, 9.55, 5.05, 50.09, 0.07, 54.4, 11.32, 8.72, 13.15, 15.2, 9.0, 16.39, 27.79, 16.07, 12.19, 0.0, 2.67, 7.98, 8.08, 2.74, 20.76, 17.18, 0.73, 7.3, 3.8, 29.67, 16.62, 10.87, 3.95, 1.03, 25.0, 45.22, 23.28, 0.0, 22.26, 5.07, 23.38, 5.48, 13.33, 3.82, 28.13, 16.67, 10.38, 0.48, 49.26, null, 12.99, 5.71, 55.3, 0.0, 0.77, 20.0, 19.61, 5.1, 0.99, 0.0, 21.68, 26.71, 10.0, 0.38, 5.6, 15.94, 3.54, 31.29, 13.04, 2.87, 0.0, 27.87, 8.7, 7.36, 0.46, 7.6, 2.89, 18.95, 45.91, 21.75, 3.95, 1.64, 13.6, 40.82, 7.33, 40.54, 12.9, 19.44, 6.56, 13.04, 17.95, 21.2, 16.67, 6.25, 1.67, 12.78, 33.35, 2.22, 6.98, 1.64, 30.16, 8.6, 0.64, 1.67, 12.08, 26.07, 13.86, 6.83, 0.37, 10.35, 6.54, 10.42, 25.22, 24.0, 6.61, 4.52, 29.36, 46.15, 23.61, 14.62, 17.86, 30.93, 3.72, 2.33, 0.0, 25.88, 56.21, 0.6, 23.46,