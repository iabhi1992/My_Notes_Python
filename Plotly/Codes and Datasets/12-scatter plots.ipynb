# %%
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
import plotly.graph_objs as go

import numpy as np

# %% [markdown]
# **Generate a sets of 400 x and y coordinates**
#
# These will be used in our scatter plot

# %%
n = 400

random_x = np.random.randn(n)

random_y = np.random.randn(n)

# %% [markdown]
# **Creating a trace from a Plotly Scatter object**
#
# This will generate points using the X and Y coordinates which we supply. The X and Y coordinates are paired by their index.
#
# Setting the mode to 'markers' will ensure that only the points are plotted, and are not connected by a line. The default mode is 'lines' where the points are connected by a line in the order of their index. i.e. (x0, y0) to (x1, y1) to (x2, y2) etc.
#
# The trace or graph is effectively a JSON object containing the details needed for a plot.

# %%
trace = go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers'
)

trace
# Out:
# Scatter({
#     'mode': 'markers',
#     'x': array([ 0.98694682,  0.10521611,  0.67304082, ...,  2.10732737,  0.06175722,
#                 -0.3316826 ]),
#     'y': array([ 0.14946336, -1.13309151, -0.01051156, ...,  1.95262836, -0.85752749,
#                  0.68474431])
# })

# %% [markdown]
# **The data supplied for a plotly plot needs to be a list**
#
# This is because we can have multiple traces on the same plot (as we shall soon see)

# %%
data_scatterplot=[trace]

# %% [markdown]
# **Produce the plot using iplot**
#
# Hover over each point to view the X and Y coordinates of the point

# %%
offline.iplot(data_scatterplot)
# Out:
# <div id="d599ffdc-8271-4349-8b60-21cf5c2ba493" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d599ffdc-8271-4349-8b60-21cf5c2ba493", [{"mode": "markers", "x": [0.9869468161145442, 0.1052161109351214, 0.6730408249810066, -0.5368385534192427, -0.5513456416184116, 1.0543354867196844, 0.12974730919154998, 0.9664795062564647, -0.197528000410552, -0.3941024273044099, 0.17347797810887272, -0.07137295115024275, -0.45490760415375664, -0.14492671801782728, -0.4911130809604808, -1.718362001720939, 0.7170777423964392, 1.0500819386739633, 1.6372984067744925, -1.0777012344060746, 0.07545918966447317, -1.2090589572128194, 1.4336348601841153, -0.7091745764518051, 0.9158962445451291, 1.210947045992917, -0.4632418791764463, -0.3596477968526898, 1.225470995608147, 1.2960810715745585, -0.06671547089346708, 0.011824598618645302, 0.042196590646456984, -1.1391825880469126, -0.4119572188639612, -0.2898111774330208, -0.1645216403147865, 0.09683183977929956, 1.5626392037947985, 1.1552900976779767, -1.0734698195167922, 0.506232181573754, 0.17009141384612, -0.848473418030779, 1.8692928642829807, 0.2049519978710788, 1.282441807257746, 0.8636871625194587, -0.8616928868214734, 2.188414751360402, -0.9587724362493715, 0.773142850890422, -2.2004900256643074, -2.068034134210045, 0.22077447425882704, 0.9298928429335392, -0.7949706850294541, 1.0149965195213597, 0.04640167304508811, 0.5651786807052679, -1.567642033894543, -0.06752978644204181, 0.024708193872227478, 0.1766517175873979, -2.148744124006518, -0.4585864295001685, -0.7911112268585949, 0.6845290848663158, -0.30260992379788954, -0.7533112909931526, -1.7256685777985379, -0.8343537664415509, 0.17446384279621133, 0.7151654987771578, 0.9654936532398983, 1.4898025969551842, 1.0683802864486698, 0.044829850367103505, 0.9042696311422881, 0.042648266500378146, -2.1333971883590452, -0.057623418668741176, 0.4739693888605022, 1.3749540922513361, -0.851770753838439, 0.02754360292895353, -1.2326977056839186, -0.8240294284311156, -1.754623403502903, 0.7071882152351725, 0.21138232209525182, -1.940887136986792, 1.1806167545971222, 0.7311982107953383, 1.2758582528555629, 0.03898704157322497, -0.10159013488453972, -0.6918116673953935, 0.2764037573623504, 1.1273801574262705, -0.36389495870149696, -0.69817923705231, -0.482244802446619, -0.8273897607468559, 0.6854563061480162, -0.6744382985880664, -0.4910405408930465, 0.008309589037511228, -1.3132957251144926, 0.39885670035710385, 1.1946988586514662, -0.22037065684554064, 0.9633075722491828, -1.5401374441502553, 1.3743762126147299, -0.6070743435139957, -0.2995681132249827, -0.12982163978239977, 1.0392904517275268, 1.096220810987713, -0.5314688183184143, 0.3149777211448625, 0.5492220659758469, -1.276212166890373, -1.072569184249059, 1.4515276366541645, 0.6252629704991727, 0.180750137754743, 0.31249884350821117, 1.5002954969080666, 0.5642823587611978, 0.4015935747667618, 0.377151507515346, 0.4696753212132472, -0.37086967090718687, -0.9059722417008776, -1.2926915603028577, 0.4750468963719272, 0.9197596556931291, 2.037170436200896, -0.48369413211187956, 0.865562782414394, 0.8568241619863293, -1.7749181088943882, -0.03830977509137582, 1.6656093352167303, -1.1444548858999921, -0.34341704534751494, 0.49220412531235835, -0.36119253183962446, -0.22446377370521922, 2.0405885497141747, -0.412184072088471, 1.942545777937372, -0.5630088028535495, -1.2535927912007305, 0.4307346667758629, 0.3796547375968045, 0.17089205427388596, -0.5464215685586394, 1.9879592811739126, 0.9891549621038918, 0.578091382674696, -0.38554724908315696, 0.968592946973283, 0.7019612489008689, 0.044979955925514355, 0.5675721530914657, -0.3170329931695496, -1.4517915495114697, -0.9870275996385939, -1.4411740999466005, 1.859391834098796, -0.8526417300309896, 1.6467057562552219, 0.191956066598696, 1.17534793441573, 0.09550912795856598 ...

# %% [markdown]
# **Multiple Scatter plots in one plot**
#
# Here we produce multiple graphs on the same plot. We do that by having a single set of x coordinates shared by 3 sets of y coordinates. We space out the y values for each graph so that they do not overlap on the plot.

# %% [markdown]
# **Generate the X coordinates**
#
# We will create 100 points in each graph. Start off by creating 100 evenly spaced x values in the interval (0,1). These values are ordered (so that lines connecting them move left to right rather than all over the place)

# %%
n = 100

random_x = np.linspace(0, 1, n)

# %% [markdown]
# **Generate 3 sets of Y coordinates**
#
# These are spaced with offsets of 10 so that they do not overlap. There is no ordering of values here.

# %%
random_y0 = np.random.randn(n)+10

random_y1 = np.random.randn(n)

random_y2 = np.random.randn(n)-10

# %% [markdown]
# **The first trace/graph contains only markers**
#
# These will only be points which are not connected by a line. A name is assigned to the trace - this will appear in the legend of the plot

# %%
trace0 = go.Scatter(
    x = random_x,
    y = random_y0,
    mode = 'markers'
)

# %% [markdown]
# **The second trace has only a line**
#
# The points are connected by a line, but without markers for the points

# %%
trace1 = go.Scatter(
    x = random_x,
    y = random_y1,
    mode = 'lines'
)

# %% [markdown]
# **The third trace has both markers and a connecting line**

# %%
trace2 = go.Scatter(
    x = random_x,
    y = random_y2,
    mode = 'lines'
)

# %% [markdown]
# **The data for our plot now comprises three traces**
#
# These are all contained in a list which is used by the plot

# %%
data_scatterplots = [trace0, trace1, trace2]

# %% [markdown]
# **Generate the plot**
#
# Plotly is smart enough to create a legend automatically, though it has assigned some default names for the traces.

# %%
offline.iplot(data_scatterplots)
# Out:
# <div id="244caa8b-1969-489b-ace8-e1924f185a45" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("244caa8b-1969-489b-ace8-e1924f185a45", [{"mode": "markers", "x": [0.0, 0.010101010101010102, 0.020202020202020204, 0.030303030303030304, 0.04040404040404041, 0.05050505050505051, 0.06060606060606061, 0.07070707070707072, 0.08080808080808081, 0.09090909090909091, 0.10101010101010102, 0.11111111111111112, 0.12121212121212122, 0.13131313131313133, 0.14141414141414144, 0.15151515151515152, 0.16161616161616163, 0.17171717171717174, 0.18181818181818182, 0.19191919191919193, 0.20202020202020204, 0.21212121212121213, 0.22222222222222224, 0.23232323232323235, 0.24242424242424243, 0.25252525252525254, 0.26262626262626265, 0.27272727272727276, 0.2828282828282829, 0.29292929292929293, 0.30303030303030304, 0.31313131313131315, 0.32323232323232326, 0.33333333333333337, 0.3434343434343435, 0.3535353535353536, 0.36363636363636365, 0.37373737373737376, 0.38383838383838387, 0.393939393939394, 0.4040404040404041, 0.4141414141414142, 0.42424242424242425, 0.43434343434343436, 0.4444444444444445, 0.4545454545454546, 0.4646464646464647, 0.4747474747474748, 0.48484848484848486, 0.494949494949495, 0.5050505050505051, 0.5151515151515152, 0.5252525252525253, 0.5353535353535354, 0.5454545454545455, 0.5555555555555556, 0.5656565656565657, 0.5757575757575758, 0.5858585858585859, 0.595959595959596, 0.6060606060606061, 0.6161616161616162, 0.6262626262626263, 0.6363636363636365, 0.6464646464646465, 0.6565656565656566, 0.6666666666666667, 0.6767676767676768, 0.686868686868687, 0.696969696969697, 0.7070707070707072, 0.7171717171717172, 0.7272727272727273, 0.7373737373737375, 0.7474747474747475, 0.7575757575757577, 0.7676767676767677, 0.7777777777777778, 0.787878787878788, 0.797979797979798, 0.8080808080808082, 0.8181818181818182, 0.8282828282828284, 0.8383838383838385, 0.8484848484848485, 0.8585858585858587, 0.8686868686868687, 0.8787878787878789, 0.888888888888889, 0.8989898989898991, 0.9090909090909092, 0.9191919191919192, 0.9292929292929294, 0.9393939393939394, 0.9494949494949496, 0.9595959595959597, 0.9696969696969697, 0.9797979797979799, 0.98989898989899, 1.0], "y": [10.906843107869603, 10.452935744755715, 11.36886484003376, 11.57542229069073, 8.900215038071803, 11.040234147442337, 11.364989864829193, 9.563630709346985, 8.997766422450468, 10.568317440639508, 10.858938733611458, 11.074434792339833, 9.137023890767766, 10.92263937995951, 11.117359318508573, 9.73393936080911, 10.934061801140556, 10.431195735734065, 10.463878304776951, 9.748940537507737, 9.985117882461308, 10.80581615007752, 10.77715121553523, 9.353169701781404, 9.301340061804364, 11.297851136803168, 9.617688431910588, 10.44300756186126, 9.364805123737053, 9.7134356173435, 9.04388622045949, 10.011293565770174, 8.884486097474674, 11.712963515045896, 8.989374913972949, 12.16734031879178, 9.396213184673252, 9.799167970965724, 9.684081420681872, 9.799431036218454, 10.10050992680188, 10.907826343289848, 10.998806887286293, 12.76084955761883, 11.207529119459286, 11.223279656809396, 9.266463197216895, 9.688345981190661, 9.331025450884916, 9.474422984109195, 8.867313228722837, 9.013465557606454, 9.707823337325499, 9.522132019459633, 8.472419583743324, 10.909125109942556, 10.06923930106479, 9.532508910531709, 10.536310436321651, 10.416606352793515, 10.132700534606489, 9.501290359446399, 9.541061799568737, 9.180428693857985, 10.741602450465198, 11.357542469373797, 9.822944223000464, 9.288340200006523, 8.582146115006747, 8.971779253755813, 10.128162130785569, 8.77050390422903, 9.153598636106114, 11.61303182577355, 10.288091064268343, 9.118204911096845, 9.18579943027831, 8.754181893260352, 11.30270048869179, 9.108135535070614, 9.896019646749153, 8.396231618683446, 9.785960197109995, 8.76774224184427, 10.539653117261192, 10.0044 ...

# %% [markdown]
# **Style Scatter Plots**
#
# We can customize the look of the scatter plots by configuring each of its components. Here, we show how we can define the markers, lines, graph names, the axes and set a title for our plot.
#
# We also define a layout and figure instead of plotting with only the data. A figure object comprises the data plus a layout.

# %% [markdown]
# **Define a style for the marker**
#
# Among other attributes, we can set the size and color of markers. There are different ways to set the colors, but here we just use the names of some colors.

# %%
marker_style = dict(size = 8,
                    color = 'red')

# %% [markdown]
# **Define the line style**
#
# Here, we set the color and width

# %%
line_style = dict(width = 4, 
                  color = 'blue')

# %% [markdown]
# **Define the first trace**
#
# It's the same as the previous one, but with a customised marker style. We also set a name for the graph which will appear in the legend (instead of "trace 0")

# %%
trace0 = go.Scatter(
    x = random_x,
    y = random_y0,
    mode = 'markers',
    marker = marker_style,
    name = 'Markers only'
)

# %% [markdown]
# **The second trace uses the line style**
#
# We also set a name for this trace

# %%
trace1 = go.Scatter(
    x = random_x,
    y = random_y1,
    mode = 'lines',
    line = line_style,
    name = 'Lines_only'
)

# %% [markdown]
# **Define the third trace**
#
# This one uses both the line style and marker style

# %%
trace2 = go.Scatter(
    x = random_x,
    y = random_y2,
    mode = 'lines+markers',
    marker = marker_style,
    line = line_style,
    name = 'Markers + Lines'
)

# %% [markdown]
# **Each plot contains a layout which can be configured**
#
# The layout has several configurable attributes including the title and the axes. For the axes, we set the width for the zero line

# %%
layout = dict(title = 'Scatter Style',
              yaxis = dict(zerolinewidth = 5),
              xaxis = dict(zerolinewidth = 5)
             )

# %% [markdown]
# **Define the data for our plot**
#
# Just as before, it contains the 3 traces we have created. This time with the additional styling.

# %%
data_scatterplot = [trace0, trace1, trace2]

# %% [markdown]
# **Define a figure object**
#
# A figure is simply an object which contains the data and the layout definition for a plot. This time we will plot a figure object instead of a data object.

# %%
fig = dict(data = data_scatterplot, 
           layout = layout)

# %% [markdown]
# **Plot the figure**

# %%
offline.iplot(fig)
# Out:
# <div id="e9ca018e-cc6c-4cce-85a2-aec6cf6fdbcd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e9ca018e-cc6c-4cce-85a2-aec6cf6fdbcd", [{"marker": {"color": "red", "size": 8}, "mode": "markers", "name": "Markers only", "x": [0.0, 0.010101010101010102, 0.020202020202020204, 0.030303030303030304, 0.04040404040404041, 0.05050505050505051, 0.06060606060606061, 0.07070707070707072, 0.08080808080808081, 0.09090909090909091, 0.10101010101010102, 0.11111111111111112, 0.12121212121212122, 0.13131313131313133, 0.14141414141414144, 0.15151515151515152, 0.16161616161616163, 0.17171717171717174, 0.18181818181818182, 0.19191919191919193, 0.20202020202020204, 0.21212121212121213, 0.22222222222222224, 0.23232323232323235, 0.24242424242424243, 0.25252525252525254, 0.26262626262626265, 0.27272727272727276, 0.2828282828282829, 0.29292929292929293, 0.30303030303030304, 0.31313131313131315, 0.32323232323232326, 0.33333333333333337, 0.3434343434343435, 0.3535353535353536, 0.36363636363636365, 0.37373737373737376, 0.38383838383838387, 0.393939393939394, 0.4040404040404041, 0.4141414141414142, 0.42424242424242425, 0.43434343434343436, 0.4444444444444445, 0.4545454545454546, 0.4646464646464647, 0.4747474747474748, 0.48484848484848486, 0.494949494949495, 0.5050505050505051, 0.5151515151515152, 0.5252525252525253, 0.5353535353535354, 0.5454545454545455, 0.5555555555555556, 0.5656565656565657, 0.5757575757575758, 0.5858585858585859, 0.595959595959596, 0.6060606060606061, 0.6161616161616162, 0.6262626262626263, 0.6363636363636365, 0.6464646464646465, 0.6565656565656566, 0.6666666666666667, 0.6767676767676768, 0.686868686868687, 0.696969696969697, 0.7070707070707072, 0.7171717171717172, 0.7272727272727273, 0.7373737373737375, 0.7474747474747475, 0.7575757575757577, 0.7676767676767677, 0.7777777777777778, 0.787878787878788, 0.797979797979798, 0.8080808080808082, 0.8181818181818182, 0.8282828282828284, 0.8383838383838385, 0.8484848484848485, 0.8585858585858587, 0.8686868686868687, 0.8787878787878789, 0.888888888888889, 0.8989898989898991, 0.9090909090909092, 0.9191919191919192, 0.9292929292929294, 0.9393939393939394, 0.9494949494949496, 0.9595959595959597, 0.9696969696969697, 0.9797979797979799, 0.98989898989899, 1.0], "y": [10.906843107869603, 10.452935744755715, 11.36886484003376, 11.57542229069073, 8.900215038071803, 11.040234147442337, 11.364989864829193, 9.563630709346985, 8.997766422450468, 10.568317440639508, 10.858938733611458, 11.074434792339833, 9.137023890767766, 10.92263937995951, 11.117359318508573, 9.73393936080911, 10.934061801140556, 10.431195735734065, 10.463878304776951, 9.748940537507737, 9.985117882461308, 10.80581615007752, 10.77715121553523, 9.353169701781404, 9.301340061804364, 11.297851136803168, 9.617688431910588, 10.44300756186126, 9.364805123737053, 9.7134356173435, 9.04388622045949, 10.011293565770174, 8.884486097474674, 11.712963515045896, 8.989374913972949, 12.16734031879178, 9.396213184673252, 9.799167970965724, 9.684081420681872, 9.799431036218454, 10.10050992680188, 10.907826343289848, 10.998806887286293, 12.76084955761883, 11.207529119459286, 11.223279656809396, 9.266463197216895, 9.688345981190661, 9.331025450884916, 9.474422984109195, 8.867313228722837, 9.013465557606454, 9.707823337325499, 9.522132019459633, 8.472419583743324, 10.909125109942556, 10.06923930106479, 9.532508910531709, 10.536310436321651, 10.416606352793515, 10.132700534606489, 9.501290359446399, 9.541061799568737, 9.180428693857985, 10.741602450465198, 11.357542469373797, 9.822944223000464, 9.288340200006523, 8.582146115006747, 8.971779253755813, 10.128162130785569, 8.77050390422903, 9.153598636106114, 11.61303182577355, 10.288091064268343, 9.118204911096845, 9.18579943027831, 8.754181893260352, 11.30270048869179, 9.108135535070614, 9.896019646749153, 8.396231618683446, 9 ...

# %% [markdown]
# **Using a color scale**
#
# A color scale will set the color of an object (e.g. a marker) according to a particular value. This will allow the visualization of an extra dimension in a plot (a 3rd dimension in a 2D and 4th in a 3D plot).

# %% [markdown]
# **Define x, y and z values**
#
# Similar to the scatter plot we plotted right in the beginning, this time with an added Z dimension

# %%
n = 400

random_x = np.random.randn(n)

random_y = np.random.randn(n)

random_z = np.random.randn(n)

# %% [markdown]
# **Colorscales**
#
# Plotly uses the Matplotlib colormaps for its colorscales. The list of available colorscales can be found here: https://matplotlib.org/examples/color/colormaps_reference.html
#
# The way this works is that for a given range of values (in our example, the range of Z values) the colorscale is created such that a value will correspond to a color on the colorscale.

# %% [markdown]
# **Generate the trace with the details for the colorscale**
#
# Here, the we define our scatter trace to color the markers according to the value of the Z coordinate, and using the colorscale 'viridis'.
#
# showscale = True will ensure the colorscale is portrayed on the plot.
#
# We also define the text which will be visible when we hover over a point. We set this to the Z value of the point so that we can match it to the color in the colorscale.

# %%
trace = go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers',
    marker= dict(size = 14,
                 color = random_z,
                 colorscale = 'Viridis',
                 showscale = True),
    text = random_z
 )

# %%
data_scatterplot = [trace]

# %% [markdown]
# **Define the layout**
#
# The Layout can also be defined using the go.Layout object rather than a dictionary.
#
# By default, when hovering over a graph, the y value is displayed near the cursor, and the x value near the X axis. This is when the hovermode is 'x'.
#
# Setting the hovermode to 'y' will cause the x value to be displayed at the cursor and y value on the Y axis. We use the 'closest' hovermode to display the (x,y) and hover text of the closest marker from the cursor.

# %%
layout = go.Layout(title = 'Scatter with Colorscale',
                   hovermode = 'closest')

# %% [markdown]
# **Define the figure**
#
# Like the layout, there is also a go.Figure object

# %%
fig = go.Figure(data = data_scatterplot, 
                layout = layout)

# %% [markdown]
# **Plot the data**
#
# Hover over the markers to view the Z value and match it to the colorscale on the right

# %%
offline.iplot(fig)
# Out:
# <div id="1fb67f8e-fd4d-45e1-8779-e4d457ebc642" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '1fb67f8e-fd4d-45e1-8779-e4d457ebc642',
#             [{"marker": {"color": [1.0541120229243308, -0.15843853046362666, -0.36454142539369255, -0.9994767687602985, 1.3291896710193383, 0.05170750086890383, 0.4361952608110103, 0.9163230733242941, -0.7313828781995086, -1.8808490020206317, -0.43583298214786875, 0.617014065872037, 0.20845846010437374, 0.7676102763313983, -0.11265226508076477, 1.889099808274447, 0.6483207254425296, -1.2015898412023294, -1.092930511062757, 0.9993520454720805, 0.8349377603044836, -0.2956175042843734, 1.2125057595953228, -1.4556390653353546, -0.0632250325937681, 0.2920200305914723, 1.7184608247443236, -1.5719757281992357, 0.3308180240719039, 1.2931693759692777, 1.9402606665779967, -1.1165435164795543, -0.6261741881479786, -0.3341550588219414, 0.08123138541048634, 1.6037739094451537, 2.198690052086645, 0.7114600940587152, 1.07269409608056, -0.8583965819140377, 1.8566545570075685, -0.020922531191214136, -1.0827232391936097, 1.3568063866407136, 0.7566177959490473, 0.5168489685649411, 2.104437744928999, -0.3201983459506043, 2.0205987999107746, 0.8209185534321032, 0.8451156016591541, 1.6617867125314294, -1.0092516338036763, -0.6754926594375713, -0.007540934531580232, -0.559600386587827, -0.5104817411136733, 0.7184188239626673, -2.0097549290875003, -0.9237507480961217, 0.5724454793194315, -1.135556411245106, 0.18575719256827875, 2.1581115603255214, -0.32355988462577745, -1.941982994820464, -2.313961062200419, -0.09566242391457654, -0.5823486958663313, 0.9339498479825541, 0.506315779084727, 1.402966171607226, 2.145779062397581, -3.320208132240934, 0.9018630701071614, 1.1807467416222117, -0.5903977228613373, -0.5330377327590038, 0.4278487426182865, 0.6021292990072991, 1.1705229929154959, 2.2687119719138598, -1.625787290918065, 2.5563132210363433, 0.07989144085670476, -0.8237377226613708, 0.8244880271082254, 0.09736086771000062, 0.5331334146338272, 1.0030759109830778, 0.7997552404096585, -0.19996873371618548, -0.11213902769673943, 0.12020320027449537, -0.4722395786926777, -0.2294676711949234, -0.47473286190425484, 0.9804468131346906, 0.06451313785820786, 0.11532338366420868, -0.4201452285187685, 1.3280211684591408, 0.6353683416482485, -0.6082327521507166, 1.1214264301239805, -0.5527148253180505, -0.6728856822414772, -0.2908345791916326, -2.2095697446511267, 0.8545220830172109, -1.450136803582119, 0.350706040795284, -0.6970321816440783, -0.17904026239979073, -1.3273843006464456, 0.6074341205012257, -0.3846551268155794, 1.538316773644462, -1.590432623730817, 2.373056671161113, -0.29865955432955144, 0.5748088261970228, 1.3465721409232072, -1.1158870630388282, -0.0597385334485079, -1.428848419883844, 1.1797243852358585, 0.11896905818295535, 0.3810036429461959, -0.8233241325232864, 1.1564030540971546, -0.49235591793537137, -0.9774924138412765, -1.9386566893999735, -1.4578271462188401, -0.6846636086041946, 0.6687909239576274, 0.36906082784828886, 1.0252987606455854, 1.118015608788237, 1.2803599895295315, 0.955097801789702, 0.05153929544801466, 0.345980231281546, 1.434089259250609, 1.2264140971493376, 0.7894227525127124, -0.2274487841385525, 2.576139665269498, -1.7424124571965036, -0.38273133442236446, 0.9939649462989961, 1.4813093241725646, 1.2801421161632953, -0.8742358578380279, -0.5864937365283382, -0.19228159584173396, -0.293669337050837, -0.38478672013998466, 0.09550652897355585, 1.964486248043561, 1.2829450426419042, -1.0471918180601114, 1.0145151361682754, 0.45406279460944915, 1.3901182075744234, 1.7460432987788954, -0.08532138919662273, -0.9794522249205094, 0.18037840421165424, 0.9950162126108669, -0.8704971068149682, 0.8732100154581867, 0.10306717250149677, -1.4140505262380385, 1.0836123613668631, -0.48146946355241704, -0.22993619135513504, -2.075802158241739, -1.2338449054934175, 0.28653237014363664, -0.5699789701938118, 1.3509350066484873, 0.7878842881609667, 1.0284101811934772, 0.35012499297406463, -0.19017370106740128, -0.30635035963042595, 0.14393117490368362, 0.5623757073514023, 0.5139362814979557, 0.6241694539038053, -0.9901098313725858, 1.1649 ...

# %% [markdown]
# **Import the Pandas library**
#
# This will help us load a dataset

# %%
import pandas as pd

# %% [markdown]
# **download the dataset**
#
# dataset location:https://github.com/queryverse/VegaDatasets.jl/blob/master/data/data/countries.json

# %%
country_data = pd.read_csv('./datasets/countries.csv')

# %% [markdown]
# **Preview the data**
#
# The contries dataset shows total fertility and life except over. for listed countries from 1955 to 2000

# %%
country_data.head()
# Out:
#                             index      country  fertility  life_expect  \
# 0  Data courtesy of Gapminder.org  Afghanistan        7.7       30.332
# 1                             NaN  Afghanistan        7.7       31.997
# 2                             NaN  Afghanistan        7.7       34.020
# 3                             NaN  Afghanistan        7.7       36.088
# 4                             NaN  Afghanistan        7.7       38.438
#
#    n_fertility  n_life_expect  p_fertility  p_life_expect  year
# 0          7.7         31.997          NaN            NaN  1955
# 1          7.7         34.020          7.7         30.332  1960
# 2          7.7         36.088          7.7         31.997  1965
# 3          7.7         38.438          7.7         34.020  1970
# 4          7.8         39.854          7.7         36.088  1975

# %% [markdown]
# **Generate the trace**
#
# The data we will plot includes:
#
# * country on the X axis
# * Year on the Y axis
# * countries life expectancy represented by a color from the colorscale
# We use the Jet colorscale in this example. The opacity of each of the markers can also be set.
#
# This allows us to assess just by looking at the plot what the life expectancy was for a particular year for a country. So we can spot any changes in life expectancy quite easily

# %%
trace= go.Scatter(
    
         x = country_data['country'],
        
         y = country_data['year'],
    
         mode = 'markers',
    
         marker = dict(size= 8,
                    color=country_data['life_expect'],
                    colorscale='Jet',
                    showscale=True,
                    opacity= 0.5
                   ),
    
        text = country_data['life_expect']
)

# %%
data=[trace]

# %% [markdown]
# **Define the layout**

# %%
layout= go.Layout(
    
    title= 'Life Expectaion in Different Countries',
    
    hovermode= 'closest',
    
    xaxis= dict(title= 'Countries'),
    
    yaxis=dict(title= 'Year')
)

# %%
fig= go.Figure(data=data, 
               layout=layout)

# %%
offline.iplot(fig)
# Out:
# <div id="f5888cb3-4c96-4721-ac9d-98b4861ed29b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'f5888cb3-4c96-4721-ac9d-98b4861ed29b',
#             [{"marker": {"color": [30.331999999999997, 31.997, 34.02, 36.088, 38.438, 39.854, 40.821999999999996, 41.674, 41.763000000000005, 42.129, 64.399, 65.142, 65.634, 67.065, 68.48100000000001, 69.942, 70.774, 71.868, 73.275, 74.34, 64.381, 66.60600000000001, 68.336, 70.941, 71.83, 74.116, 74.494, 74.108, 73.01100000000001, 73.45100000000001, 70.33, 70.93, 71.1, 71.93, 73.49, 74.74, 76.32, 77.56, 78.83, 80.37, 67.48, 69.54, 70.14, 70.63, 72.17, 73.18, 74.94, 76.04, 77.51, 78.98, 62.405, 64.209, 65.795, 66.515, 67.199, 67.874, 69.524, 69.171, 68.472, 71.068, 39.348, 41.216, 43.453, 45.251999999999995, 46.923, 50.00899999999999, 52.818999999999996, 56.018, 59.412, 62.013000000000005, 62.57, 65.87, 67.62, 69.42, 71.27, 72.695, 74.027, 74.89399999999999, 74.91199999999999, 75.97, 69.24, 70.25, 70.94, 71.44, 72.8, 73.93, 75.35, 76.46, 77.53, 78.32, 41.89, 43.428000000000004, 45.032, 46.714, 50.023, 53.858999999999995, 57.251000000000005, 59.957, 62.05, 63.883, 53.285, 55.665, 57.632, 59.504, 61.489, 63.336000000000006, 65.205, 67.057, 69.388, 71.006, 69.96, 71.3, 72.13, 72.88, 74.21, 75.76, 76.86, 77.95, 78.61, 79.77, 56.074, 57.924, 60.523, 63.441, 67.05199999999999, 70.565, 72.492, 74.126, 75.816, 77.86, 50.54896, 44.50136, 58.381119999999996, 63.118880000000004, 63.96736, 65.525, 67.274, 68.69, 70.426, 72.028, 55.118, 57.863, 59.963, 61.623000000000005, 63.836999999999996, 66.653, 67.768, 68.421, 70.313, 71.682, 60.026, 62.842, 65.42399999999999, 67.84899999999999, 70.75, 73.45, 74.752, 75.71300000000001, 77.26, 78.123, 64.77, 67.13, 68.5, 69.61, 70.64, 70.46, 71.52, 72.527, 73.68, 74.876, 62.325, 65.24600000000001, 68.29, 70.723, 72.649, 73.717, 74.17399999999999, 74.414, 76.15100000000001, 77.158, 49.828, 53.458999999999996, 56.751000000000005, 59.631, 61.788000000000004, 63.727, 66.046, 68.457, 69.957, 70.847, 51.356, 54.64, 56.678000000000004, 58.79600000000001, 61.31, 64.342, 67.23100000000001, 69.613, 72.312, 74.173, 44.443999999999996, 46.992, 49.293, 51.137, 53.318999999999996, 56.006, 59.797, 63.674, 67.217, 69.806, 48.57, 52.306999999999995, 55.855, 58.207, 56.696000000000005, 56.604, 63.153999999999996, 66.798, 69.535, 70.734, 67.49, 68.75, 69.83, 70.87, 72.52, 74.55, 74.83, 75.7, 77.13, 78.37, 68.93, 70.51, 71.55, 72.38, 73.83, 74.89, 76.34, 77.46, 78.64, 79.59, 62.625, 64.64399999999999, 66.654, 68.158, 69.634, 69.638, 70.45, 70.465, 70.49, 70.476, 69.1, 70.3, 70.8, 71.0, 72.5, 73.8, 74.847, 76.07, 77.34, 78.67, 67.86, 69.51, 71.0, 72.34, 73.68, 75.24, 76.67, 77.03, 77.869, 78.256, 63.114, 63.608000000000004, 64.09100000000001, 64.577, 65.035, 65.503, 66.002, 66.469, 66.986, 67.74600000000001, 40.696, 43.59, 46.243, 48.042, 49.923, 51.461000000000006, 53.636, 55.089, 56.67100000000001, 58.137, 64.75, 67.65, 70.0, 72.0, 73.6, 75.45, 76.2, 77.601, 80.0, 81.495, 73.47, 73.68, 73.73, 74.46, 76.11, 76.99, 77.23, 78.77, 78.95, 80.5, 40.249, 43.605, 47.193000000000005, 50.651, 54.208, 56.596000000000004, 58.553000000000004, 60.223, 61.765, 62.879, 39.918, 42.518, 45.964, 49.203, 52.702, 56.159, 60.137, 62.681000000000004, 66.041, 68.58800000000001, 47.181000000000004, 49.325, 52.468999999999994, 55.233999999999995, 57.702, 59.62, 63.04, 65.742, 68.042, 69.45100000000001, 48.437, 51.457, 54.458999999999996, 56.95, 60.413000000000004, 62.038000000000004, 65.044, 59.461000000000006, 58.81100000000001, 57.04600000000001, 68.9, 70.29, 71.08, 71.28, 72.03, 73.1, 74.36, 75.467, 76.122, 77.783, 67.84, 69.39, 70.75, 71.63, 73.06, 74.45, 75.6, 76.93, 78.26899999999999, 79.696, 67.81, 69.24, 71.06, 72.19, 73.48, 74.98, 76.42, 77.44, 78.82, 80.24, 62.61, 65.61, 67.51, 69.0, 70.11, 71.21, 71.77, 71.766, 72.262, 72.047, 65.5, 68.73, 71.43, 73.42, 75.38, 77.11, 78.67, 79.36, 80.69, 82.0, 44.68600000000001, 47.949, 50.653999999999996, 53.559, 56.155, 58.766000000000005, 59.339, 59.285, 54.407, 50.992, 54.081, 56.656000000000006, 59.942, 63.983000000000004, 67.15899999999999, 69.1, 70.64699999999999, 69.97800000000001, 67.727, 66.66 ...
