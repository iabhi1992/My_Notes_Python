# %% [markdown]
# create traces

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# Data is obtained from https://github.com/sandialabs/slycat-data/blob/master/cars.csv

# %%
import pandas as pd
cars_data = pd.read_csv('datasets/cars.csv', sep=';')
cars_data.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0       130.0
# 1          Buick Skylark 320  15.0          8         350.0       165.0
# 2         Plymouth Satellite  18.0          8         318.0       150.0
# 3              AMC Rebel SST  16.0          8         304.0       150.0
# 4                Ford Torino  17.0          8         302.0       140.0
#
#    Weight  Acceleration  Model Origin
# 0  3504.0          12.0     70     US
# 1  3693.0          11.5     70     US
# 2  3436.0          11.0     70     US
# 3  3433.0          12.0     70     US
# 4  3449.0          10.5     70     US

# %%
cars_data_cyl = cars_data.loc[cars_data['Cylinders'] == 8]
cars_data_cyl.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0       130.0
# 1          Buick Skylark 320  15.0          8         350.0       165.0
# 2         Plymouth Satellite  18.0          8         318.0       150.0
# 3              AMC Rebel SST  16.0          8         304.0       150.0
# 4                Ford Torino  17.0          8         302.0       140.0
#
#    Weight  Acceleration  Model Origin
# 0  3504.0          12.0     70     US
# 1  3693.0          11.5     70     US
# 2  3436.0          11.0     70     US
# 3  3433.0          12.0     70     US
# 4  3449.0          10.5     70     US

# %% [markdown]
# **Examine the two fields we will use in our plots**
#
# View the distribution of values for these columns. The box plot will help us visualize this data

# %%
cars_data_cyl[['Displacement', 'Horsepower']].describe()
# Out:
#        Displacement  Horsepower
# count    108.000000  108.000000
# mean     345.203704  158.453704
# std       46.034680   27.942325
# min      260.000000   90.000000
# 25%      305.000000  140.000000
# 50%      350.000000  150.000000
# 75%      360.000000  175.000000
# max      455.000000  230.000000

# %% [markdown]
# **The first boxplot will model the Displacement**

# %%
trace0 = go.Box(y = cars_data_cyl['Displacement'], 
                name = 'Displacement')

# %% [markdown]
# **The second boxplot will model the Horsepower**

# %%
trace1 = go.Box(y = cars_data_cyl['Horsepower'], 
                name = 'Horsepower')

# %% [markdown]
# **plot the data**

# %%
data = [trace0, trace1]

offline.iplot(data)
# Out:
# <div id="ee702d58-9c7a-4208-9b76-5c10247d773a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ee702d58-9c7a-4208-9b76-5c10247d773a", [{"name": "Displacement", "y": [307.0, 350.0, 318.0, 304.0, 302.0, 429.0, 454.0, 440.0, 455.0, 390.0, 350.0, 351.0, 383.0, 360.0, 383.0, 340.0, 302.0, 400.0, 455.0, 360.0, 307.0, 318.0, 304.0, 350.0, 400.0, 351.0, 318.0, 383.0, 400.0, 400.0, 350.0, 400.0, 318.0, 351.0, 304.0, 429.0, 350.0, 350.0, 400.0, 304.0, 307.0, 302.0, 318.0, 350.0, 304.0, 350.0, 302.0, 318.0, 429.0, 400.0, 351.0, 318.0, 440.0, 455.0, 360.0, 400.0, 400.0, 360.0, 350.0, 350.0, 400.0, 318.0, 350.0, 302.0, 350.0, 318.0, 302.0, 304.0, 400.0, 350.0, 318.0, 351.0, 262.0, 302.0, 305.0, 318.0, 304.0, 351.0, 318.0, 350.0, 350.0, 302.0, 318.0, 305.0, 260.0, 318.0, 302.0, 400.0, 350.0, 400.0, 351.0, 260.0, 318.0, 302.0, 305.0, 302.0, 318.0, 305.0, 302.0, 351.0, 318.0, 350.0, 351.0, 267.0, 360.0, 350.0, 260.0, 350.0], "type": "box", "uid": "fe5b410c-bc05-11e8-ba0a-6030d4660e22"}, {"name": "Horsepower", "y": [130.0, 165.0, 150.0, 150.0, 140.0, 198.0, 220.0, 215.0, 225.0, 190.0, 165.0, 153.0, 175.0, 175.0, 170.0, 160.0, 140.0, 150.0, 225.0, 215.0, 200.0, 210.0, 193.0, 165.0, 175.0, 153.0, 150.0, 180.0, 170.0, 175.0, 165.0, 175.0, 150.0, 153.0, 150.0, 208.0, 155.0, 160.0, 190.0, 150.0, 130.0, 140.0, 150.0, 175.0, 150.0, 145.0, 137.0, 150.0, 198.0, 150.0, 158.0, 150.0, 215.0, 225.0, 175.0, 150.0, 167.0, 170.0, 180.0, 145.0, 230.0, 150.0, 180.0, 140.0, 150.0, 150.0, 140.0, 150.0, 170.0, 145.0, 150.0, 148.0, 110.0, 129.0, 140.0, 150.0, 120.0, 152.0, 150.0, 180.0, 145.0, 130.0, 150.0, 145.0, 110.0, 145.0, 130.0, 180.0, 170.0, 190.0, 149.0, 110.0, 140.0, 139.0, 145.0, 139.0, 140.0, 130.0, 129.0, 138.0, 135.0, 155.0, 142.0, 125.0, 150.0, 125.0, 90.0, 105.0], "type": "box", "uid": "fe5b42b4-bc05-11e8-93fd-6030d4660e22"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# # Styling Outliers

# %% [markdown]
# **Define the first boxplot**
#
# The value of **boxpoints** decides which points are plotted separtely with markers rather than being represented by a box. The default value is 'outliers'. A value of 'all' will plot all the points outside the box (in addition to plotting the box).
#
# Other possible values for boxpoints are 'suspectedoutliers' (values outside a certain range) and False (where only a box is drawn)
#
# **boxmean** defines whether a dotted line will be drawn to represent the mean of the distribution

# %%
trace0 = go.Box(y = cars_data_cyl['Displacement'], 
                name = 'Displacement', 
                
                boxpoints = 'all',
                
                boxmean = True                
               )

# %% [markdown]
# **Define the second boxplot**
#
# A value of 'sd' for **boxmean** will also show the standard deviation for the distribution along with the mean

# %%
trace1 = go.Box(y = cars_data_cyl['Horsepower'], 
                name = 'Horsepower', 
                
                boxmean = 'sd'
               )

# %%
data = [trace0, trace1]

offline.iplot(data)
# Out:
# <div id="9029965b-c181-4533-92b8-cedb1bb94135" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9029965b-c181-4533-92b8-cedb1bb94135", [{"boxmean": true, "boxpoints": "all", "name": "Displacement", "y": [307.0, 350.0, 318.0, 304.0, 302.0, 429.0, 454.0, 440.0, 455.0, 390.0, 350.0, 351.0, 383.0, 360.0, 383.0, 340.0, 302.0, 400.0, 455.0, 360.0, 307.0, 318.0, 304.0, 350.0, 400.0, 351.0, 318.0, 383.0, 400.0, 400.0, 350.0, 400.0, 318.0, 351.0, 304.0, 429.0, 350.0, 350.0, 400.0, 304.0, 307.0, 302.0, 318.0, 350.0, 304.0, 350.0, 302.0, 318.0, 429.0, 400.0, 351.0, 318.0, 440.0, 455.0, 360.0, 400.0, 400.0, 360.0, 350.0, 350.0, 400.0, 318.0, 350.0, 302.0, 350.0, 318.0, 302.0, 304.0, 400.0, 350.0, 318.0, 351.0, 262.0, 302.0, 305.0, 318.0, 304.0, 351.0, 318.0, 350.0, 350.0, 302.0, 318.0, 305.0, 260.0, 318.0, 302.0, 400.0, 350.0, 400.0, 351.0, 260.0, 318.0, 302.0, 305.0, 302.0, 318.0, 305.0, 302.0, 351.0, 318.0, 350.0, 351.0, 267.0, 360.0, 350.0, 260.0, 350.0], "type": "box", "uid": "fe6c6aba-bc05-11e8-a88b-6030d4660e22"}, {"boxmean": "sd", "name": "Horsepower", "y": [130.0, 165.0, 150.0, 150.0, 140.0, 198.0, 220.0, 215.0, 225.0, 190.0, 165.0, 153.0, 175.0, 175.0, 170.0, 160.0, 140.0, 150.0, 225.0, 215.0, 200.0, 210.0, 193.0, 165.0, 175.0, 153.0, 150.0, 180.0, 170.0, 175.0, 165.0, 175.0, 150.0, 153.0, 150.0, 208.0, 155.0, 160.0, 190.0, 150.0, 130.0, 140.0, 150.0, 175.0, 150.0, 145.0, 137.0, 150.0, 198.0, 150.0, 158.0, 150.0, 215.0, 225.0, 175.0, 150.0, 167.0, 170.0, 180.0, 145.0, 230.0, 150.0, 180.0, 140.0, 150.0, 150.0, 140.0, 150.0, 170.0, 145.0, 150.0, 148.0, 110.0, 129.0, 140.0, 150.0, 120.0, 152.0, 150.0, 180.0, 145.0, 130.0, 150.0, 145.0, 110.0, 145.0, 130.0, 180.0, 170.0, 190.0, 149.0, 110.0, 140.0, 139.0, 145.0, 139.0, 140.0, 130.0, 129.0, 138.0, 135.0, 155.0, 142.0, 125.0, 150.0, 125.0, 90.0, 105.0], "type": "box", "uid": "fe6c6dc6-bc05-11e8-8edc-6030d4660e22"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# **More styling**

# %% [markdown]
# **Style the first boxplot**
# * **marker** defines the markers (by default only the outliers)
# * **line** configures the enclosing box lines and the whiskers. The default width is 1

# %%
trace0 = go.Box(y = cars_data_cyl['Displacement'], 
                name = 'Displacement',
                
                marker = dict(color = 'blue'),
                
                line = dict(color = 'green', 
                            width = 1)  
               )

# %% [markdown]
# **Style the second boxplot**
# * **fillcolor** sets the color with which to fill the box. The default is the line color with 50% transparency
# * **symbol** for the marker has a number of options (https://plot.ly/python/reference/#box-marker-symbol)

# %%
trace1 = go.Box(y = cars_data_cyl['Horsepower'], 
                name = 'Horsepower',
                
                fillcolor = 'bisque',
                
                marker = dict(color = 'navy', 
                              symbol = 'square'),
                
                line = dict(color = 'red')
               )

# %%
data = [trace0, trace1]

offline.iplot(data)
# Out:
# <div id="5aa8b9d2-3be0-45b9-bb2f-9a9a130b03b3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("